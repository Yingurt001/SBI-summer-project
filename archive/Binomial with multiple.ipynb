# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from scipy.stats import beta, norm, ks_2samp, wasserstein_distance
import matplotlib.pyplot as plt
import os

os.makedirs("plots", exist_ok=True)

def generate_theta_y_n_large(batch_size=256, n_min=50, n_max=100_000, log_uniform=True):
    if log_uniform:
        log_n = np.random.uniform(np.log(n_min), np.log(n_max), size=(batch_size, 1))
        n = np.round(np.exp(log_n)).astype(np.float32)
    else:
        n = np.random.randint(n_min, n_max + 1, size=(batch_size, 1)).astype(np.float32)
    theta = np.random.uniform(0, 1, size=(batch_size, 1)).astype(np.float32)
    y = np.random.binomial(n=n.astype(int), p=theta).astype(np.float32)
    return y, n, theta

def gmm_log_likelihood(theta, logits, mus, log_sigmas):
    log_sigmas = torch.clamp(log_sigmas, min=-5, max=3)
    sigmas = torch.exp(log_sigmas)
    pi = torch.softmax(logits, dim=1)
    th = theta.unsqueeze(1).expand(-1, mus.size(1))
    logp = -0.5 * ((th - mus) / sigmas) ** 2 - log_sigmas - 0.5 * np.log(2 * np.pi)
    wlogp = logp + torch.log(pi + 1e-10)
    return -torch.mean(torch.logsumexp(wlogp, dim=1))

class GMMInferenceNet(nn.Module):
    def __init__(self, num_components=3, hidden_dims=(512, 512, 256, 128)):
        super().__init__()
        self.K = num_components
        layers = []
        d = 2
        for h in hidden_dims:
            layers += [nn.Linear(d, h), nn.ReLU()]
            d = h
        layers.append(nn.Linear(d, 3 * self.K))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        out = self.net(x)
        return out[:, :self.K], out[:, self.K:2*self.K], out[:, 2*self.K:]

def train_gmm_network(model, optimizer, num_epochs=200, batch_size=256, n_min=50, n_max=100_000, steps_per_epoch=100):
    for epoch in range(num_epochs):
        total_loss = 0.0
        for _ in range(steps_per_epoch):
            y_np, n_np, theta_np = generate_theta_y_n_large(batch_size, n_min, n_max)
            x = torch.cat([
                torch.from_numpy(y_np / n_np),
                torch.from_numpy(np.log(n_np))
            ], dim=1).float()
            theta = torch.from_numpy(theta_np).squeeze(1).float()
            logits, mus, logs = model(x)
            pi = torch.softmax(logits, dim=1)
            nll = gmm_log_likelihood(theta, logits, mus, logs)
            entropy = -torch.sum(pi * torch.log(pi + 1e-8), dim=1).mean()
            loss = nll - 0.01 * entropy
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f"[GMM] Epoch {epoch + 1}/{num_epochs} | Loss: {total_loss / steps_per_epoch:.4f}")

def evaluate_gmm_fixed_n(model, fixed_n, y_values, theta_grid, num_components=3):
    plt.figure(figsize=(10, 3.5 * len(y_values)))
    for i, y in enumerate(y_values):
        alpha, beta_param = y + 1, fixed_n - y + 1
        true_pdf = beta.pdf(theta_grid, alpha, beta_param)
        x = torch.tensor([[y / fixed_n, np.log(fixed_n)]], dtype=torch.float32)
        with torch.no_grad():
            logits, mus, logs = model(x)
        pi = torch.softmax(logits, dim=1).numpy().flatten()
        mus = mus.numpy().flatten()
        sig = np.exp(logs.numpy()).flatten()
        gmm_pdf = sum(pi[k] * norm.pdf(theta_grid, mus[k], sig[k]) for k in range(num_components))
        ts = beta.rvs(alpha, beta_param, size=2000)
        ss = np.clip(np.hstack([
            np.random.normal(mus[k], sig[k], int(round(pi[k] * 2000)))
            for k in range(num_components)
        ]), 0, 1)
        ks, p = ks_2samp(ts, ss)
        wd = wasserstein_distance(ts, ss)
        ax = plt.subplot(len(y_values), 1, i + 1)
        ax.plot(theta_grid, true_pdf, 'b--')
        ax.plot(theta_grid, gmm_pdf, 'r-')
        ax.set_title(f"GMM Fixed n={fixed_n}, y={y} | KS={ks:.3f}, p={p:.3f}, W={wd:.3f}")
    plt.tight_layout()
    plt.savefig(f"plots/gmm_fixedN_{fixed_n}.png", dpi=300)
    plt.show()

def evaluate_gmm_unseen_n(model, test_cases, theta_grid, num_components=3):
    plt.figure(figsize=(10, 3.5 * len(test_cases)))
    for i, (n, y) in enumerate(test_cases):
        alpha, beta_param = y + 1, n - y + 1
        true_pdf = beta.pdf(theta_grid, alpha, beta_param)
        x = torch.tensor([[y / n, np.log(n)]], dtype=torch.float32)
        with torch.no_grad():
            logits, mus, logs = model(x)
        pi = torch.softmax(logits, dim=1).numpy().flatten()
        mus = mus.numpy().flatten()
        sig = np.exp(logs.numpy()).flatten()
        gmm_pdf = sum(pi[k] * norm.pdf(theta_grid, mus[k], sig[k]) for k in range(num_components))
        ts = beta.rvs(alpha, beta_param, size=2000)
        ss = np.clip(np.hstack([
            np.random.normal(mus[k], sig[k], int(round(pi[k] * 2000)))
            for k in range(num_components)
        ]), 0, 1)
        ks, p = ks_2samp(ts, ss)
        wd = wasserstein_distance(ts, ss)
        ax = plt.subplot(len(test_cases), 1, i + 1)
        ax.plot(theta_grid, true_pdf, 'b--')
        ax.plot(theta_grid, gmm_pdf, 'r-')
        ax.set_title(f"GMM Unseen n={n}, y={y} | KS={ks:.3f}, p={p:.3f}, W={wd:.3f}")
    plt.tight_layout()
    plt.savefig("plots/gmm_unseenN.png", dpi=300)
    plt.show()

K = 10  
hidden_dims = (512, 512, 256, 128)
gmm_model = GMMInferenceNet(num_components=K, hidden_dims=hidden_dims)
gmm_optimizer = optim.Adam(gmm_model.parameters(), lr=1e-3)
print("----- Training GMM Network -----")
train_gmm_network(gmm_model, gmm_optimizer)

theta_grid = np.linspace(0, 1, 500)
y_values_fixed = [1, 100, 2000, 8000]
test_cases_unseen = [(20000, 1), (50000, 25000), (200000, 150000)]

print("----- Evaluating GMM Fixed n=10000 -----")
evaluate_gmm_fixed_n(gmm_model, fixed_n=10000, y_values=y_values_fixed, theta_grid=theta_grid, num_components=K)
print("----- Evaluating GMM Unseen n's -----")
evaluate_gmm_unseen_n(gmm_model, test_cases_unseen, theta_grid, num_components=K)
# Out:
# ----- Training GMM Network -----
# [GMM] Epoch 1/200 | Loss: 0.1137
# [GMM] Epoch 2/200 | Loss: -0.1007
# [GMM] Epoch 3/200 | Loss: -0.2107
# [GMM] Epoch 4/200 | Loss: -0.3704
# [GMM] Epoch 5/200 | Loss: -0.1752
# [GMM] Epoch 6/200 | Loss: -0.2773
# [GMM] Epoch 7/200 | Loss: -0.5991
# [GMM] Epoch 8/200 | Loss: -0.8561
# [GMM] Epoch 9/200 | Loss: -1.5364
# [GMM] Epoch 10/200 | Loss: -0.7234
# [GMM] Epoch 11/200 | Loss: -1.6389
# [GMM] Epoch 12/200 | Loss: -1.9975
# [GMM] Epoch 13/200 | Loss: -2.1974
# [GMM] Epoch 14/200 | Loss: -1.8990
# [GMM] Epoch 15/200 | Loss: -1.6421
# [GMM] Epoch 16/200 | Loss: -1.2803
# [GMM] Epoch 17/200 | Loss: -1.0774
# [GMM] Epoch 18/200 | Loss: -2.2722
# [GMM] Epoch 19/200 | Loss: -1.9520
# [GMM] Epoch 20/200 | Loss: -1.6660
# [GMM] Epoch 21/200 | Loss: -2.3229
# [GMM] Epoch 22/200 | Loss: -2.4365
# [GMM] Epoch 23/200 | Loss: -1.2348
# [GMM] Epoch 24/200 | Loss: -1.4694
# [GMM] Epoch 25/200 | Loss: -2.2812
# [GMM] Epoch 26/200 | Loss: -1.0371
# [GMM] Epoch 27/200 | Loss: -1.6410
# [GMM] Epoch 28/200 | Loss: -2.3608
# [GMM] Epoch 29/200 | Loss: -2.2476
# [GMM] Epoch 30/200 | Loss: -1.6889
# [GMM] Epoch 31/200 | Loss: -2.4270
# [GMM] Epoch 32/200 | Loss: -2.4759
# [GMM] Epoch 33/200 | Loss: -2.4776
# [GMM] Epoch 34/200 | Loss: -1.8070
# [GMM] Epoch 35/200 | Loss: -2.5384
# [GMM] Epoch 36/200 | Loss: -2.5931
# [GMM] Epoch 37/200 | Loss: -2.6110
# [GMM] Epoch 38/200 | Loss: -2.4115
# [GMM] Epoch 39/200 | Loss: -2.5621
# [GMM] Epoch 40/200 | Loss: -2.0990
# [GMM] Epoch 41/200 | Loss: -0.9101
# [GMM] Epoch 42/200 | Loss: -1.9709
# [GMM] Epoch 43/200 | Loss: -2.6465
# [GMM] Epoch 44/200 | Loss: -2.7016
# [GMM] Epoch 45/200 | Loss: -2.5212
# [GMM] Epoch 46/200 | Loss: -2.2320
# [GMM] Epoch 47/200 | Loss: -2.2331
# [GMM] Epoch 48/200 | Loss: -2.1302
# [GMM] Epoch 49/200 | Loss: -1.8121
# [GMM] Epoch 50/200 | Loss: -2.4949
# [GMM] Epoch 51/200 | Loss: -2.4382
# [GMM] Epoch 52/200 | Loss: -2.4296
# [GMM] Epoch 53/200 | Loss: -2.5969
# [GMM] Epoch 54/200 | Loss: -2.2858
# [GMM] Epoch 55/200 | Loss: -2.4773
# [GMM] Epoch 56/200 | Loss: -2.5547
# [GMM] Epoch 57/200 | Loss: -2.5238
# [GMM] Epoch 58/200 | Loss: -2.5416
# [GMM] Epoch 59/200 | Loss: -2.4585
# [GMM] Epoch 60/200 | Loss: -2.3437
# [GMM] Epoch 61/200 | Loss: -2.3131
# [GMM] Epoch 62/200 | Loss: -2.5119
# [GMM] Epoch 63/200 | Loss: -2.4200
# [GMM] Epoch 64/200 | Loss: -2.6468
# [GMM] Epoch 65/200 | Loss: -2.2171
# [GMM] Epoch 66/200 | Loss: -2.6712
# [GMM] Epoch 67/200 | Loss: -2.4585
# [GMM] Epoch 68/200 | Loss: -2.3817
# [GMM] Epoch 69/200 | Loss: -2.5662
# [GMM] Epoch 70/200 | Loss: -2.7101
# [GMM] Epoch 71/200 | Loss: -2.0010
# [GMM] Epoch 72/200 | Loss: -2.2414
# [GMM] Epoch 73/200 | Loss: -2.1800
# [GMM] Epoch 74/200 | Loss: -1.4518
# [GMM] Epoch 75/200 | Loss: -2.1640
# [GMM] Epoch 76/200 | Loss: -1.8413
# [GMM] Epoch 77/200 | Loss: -0.9790
# [GMM] Epoch 78/200 | Loss: -1.3755
# [GMM] Epoch 79/200 | Loss: -2.0330
# [GMM] Epoch 80/200 | Loss: -2.4473
# [GMM] Epoch 81/200 | Loss: -2.4898
# [GMM] Epoch 82/200 | Loss: -2.3237
# [GMM] Epoch 83/200 | Loss: -2.3080
# [GMM] Epoch 84/200 | Loss: -2.6004
# [GMM] Epoch 85/200 | Loss: -2.5544
# [GMM] Epoch 86/200 | Loss: -2.4605
# [GMM] Epoch 87/200 | Loss: -2.5381
# [GMM] Epoch 88/200 | Loss: -2.6467
# [GMM] Epoch 89/200 | Loss: -2.7286
# [GMM] Epoch 90/200 | Loss: -2.6558
# [GMM] Epoch 91/200 | Loss: -2.2423
# [GMM] Epoch 92/200 | Loss: -2.3758
# [GMM] Epoch 93/200 | Loss: -1.9936
# [GMM] Epoch 94/200 | Loss: -2.6130
# [GMM] Epoch 95/200 | Loss: -2.1981
# [GMM] Epoch 96/200 | Loss: -2.7524
# [GMM] Epoch 97/200 | Loss: -2.0791
# [GMM] Epoch 98/200 | Loss: -2.6027
# [GMM] Epoch 99/200 | Loss: -2.4593
# [GMM] Epoch 100/200 | Loss: -2.1482
# [GMM] Epoch 101/200 | Loss: -2.5731
# [GMM] Epoch 102/200 | Loss: -2.6216
# [GMM] Epoch 103/200 | Loss: -2.5907
# [GMM] Epoch 104/200 | Loss: -2.3595
# [GMM] Epoch 105/200 | Loss: -2.6565
# [GMM] Epoch 106/200 | Loss: -2.3383
# [GMM] Epoch 107/200 | Loss: -2.5108
# [GMM] Epoch 108/200 | Loss: -2.8368
# [GMM] Epoch 109/200 | Loss: -2.1756
# [GMM] Epoch 110/200 | Loss: -2.7595
# [GMM] Epoch 111/200 | Loss: -2.5594
# [GMM] Epoch 112/200 | Loss: -2.8521
# [GMM] Epoch 113/200 | Loss: -2.7705
# [GMM] Epoch 114/200 | Loss: -2.7132
# [GMM] Epoch 115/200 | Loss: -2.5392
# [GMM] Epoch 116/200 | Loss: -2.9071
# [GMM] Epoch 117/200 | Loss: -2.9255
# [GMM] Epoch 118/200 | Loss: -2.9927
# [GMM] Epoch 119/200 | Loss: -2.7869
# [GMM] Epoch 120/200 | Loss: -2.8814
# [GMM] Epoch 121/200 | Loss: -2.9615
# [GMM] Epoch 122/200 | Loss: -2.9749
# [GMM] Epoch 123/200 | Loss: -2.9973
# [GMM] Epoch 124/200 | Loss: -2.9740
# [GMM] Epoch 125/200 | Loss: -2.3182
# [GMM] Epoch 126/200 | Loss: -2.7880
# [GMM] Epoch 127/200 | Loss: -2.5723
# [GMM] Epoch 128/200 | Loss: -2.9272
# [GMM] Epoch 129/200 | Loss: -2.9835
# [GMM] Epoch 130/200 | Loss: -2.6977
# [GMM] Epoch 131/200 | Loss: -2.9654
# [GMM] Epoch 132/200 | Loss: -2.4737
# [GMM] Epoch 133/200 | Loss: -2.9972
# [GMM] Epoch 134/200 | Loss: -2.9015
# [GMM] Epoch 135/200 | Loss: -2.9281
# [GMM] Epoch 136/200 | Loss: -3.0546
# [GMM] Epoch 137/200 | Loss: -2.8673
# [GMM] Epoch 138/200 | Loss: -2.8470
# [GMM] Epoch 139/200 | Loss: -3.0356
# [GMM] Epoch 140/200 | Loss: -2.9909
# [GMM] Epoch 141/200 | Loss: -3.0549
# [GMM] Epoch 142/200 | Loss: -2.7904
# [GMM] Epoch 143/200 | Loss: -2.9422
# [GMM] Epoch 144/200 | Loss: -3.0656
# [GMM] Epoch 145/200 | Loss: -3.0379
# [GMM] Epoch 146/200 | Loss: -2.8542
# [GMM] Epoch 147/200 | Loss: -2.8812
# [GMM] Epoch 148/200 | Loss: -3.1058
# [GMM] Epoch 149/200 | Loss: -2.3633
# [GMM] Epoch 150/200 | Loss: -2.4812
# [GMM] Epoch 151/200 | Loss: -2.9359
# [GMM] Epoch 152/200 | Loss: -3.0188
# [GMM] Epoch 153/200 | Loss: -2.8913
# [GMM] Epoch 154/200 | Loss: -3.0506
# [GMM] Epoch 155/200 | Loss: -3.0536
# [GMM] Epoch 156/200 | Loss: -2.9876
# [GMM] Epoch 157/200 | Loss: -3.0886
# [GMM] Epoch 158/200 | Loss: -3.0491
# [GMM] Epoch 159/200 | Loss: -3.0124
# [GMM] Epoch 160/200 | Loss: -3.0968
# [GMM] Epoch 161/200 | Loss: -3.1040
# [GMM] Epoch 162/200 | Loss: -3.0734
# [GMM] Epoch 163/200 | Loss: -3.0217
# [GMM] Epoch 164/200 | Loss: -3.0447
# [GMM] Epoch 165/200 | Loss: -3.0919
# [GMM] Epoch 166/200 | Loss: -3.0354
# [GMM] Epoch 167/200 | Loss: -3.0854
# [GMM] Epoch 168/200 | Loss: -3.0649
# [GMM] Epoch 169/200 | Loss: -3.0888
# [GMM] Epoch 170/200 | Loss: -3.0083
# [GMM] Epoch 171/200 | Loss: -3.0175
# [GMM] Epoch 172/200 | Loss: -3.0586
# [GMM] Epoch 173/200 | Loss: -2.4020
# [GMM] Epoch 174/200 | Loss: -2.5620
# [GMM] Epoch 175/200 | Loss: -2.9863
# [GMM] Epoch 176/200 | Loss: -3.0631
# [GMM] Epoch 177/200 | Loss: -3.0465
# [GMM] Epoch 178/200 | Loss: -2.8624
# [GMM] Epoch 179/200 | Loss: -3.0873
# [GMM] Epoch 180/200 | Loss: -3.0574
# [GMM] Epoch 181/200 | Loss: -3.0748
# [GMM] Epoch 182/200 | Loss: -3.0378
# [GMM] Epoch 183/200 | Loss: -3.1306
# [GMM] Epoch 184/200 | Loss: -2.9958
# [GMM] Epoch 185/200 | Loss: -3.0457
# [GMM] Epoch 186/200 | Loss: -3.1177
# [GMM] Epoch 187/200 | Loss: -3.0895
# [GMM] Epoch 188/200 | Loss: -3.0596
# [GMM] Epoch 189/200 | Loss: -1.2196
# [GMM] Epoch 190/200 | Loss: -2.9440
# [GMM] Epoch 191/200 | Loss: -3.0486
# [GMM] Epoch 192/200 | Loss: -3.0519
# [GMM] Epoch 193/200 | Loss: -2.9566
# [GMM] Epoch 194/200 | Loss: -3.0526
# [GMM] Epoch 195/200 | Loss: -3.0957
# [GMM] Epoch 196/200 | Loss: -3.1036
# [GMM] Epoch 197/200 | Loss: -3.0731
# [GMM] Epoch 198/200 | Loss: -3.0729
# [GMM] Epoch 199/200 | Loss: -3.1138
# [GMM] Epoch 200/200 | Loss: -3.0950
# ----- Evaluating GMM Fixed n=10000 -----
# ----- Evaluating GMM Unseen n's -----

# %%
K = 10
hidden_dims = (512, 512, 256, 128)
gmm_model = GMMInferenceNet(num_components=K, hidden_dims=hidden_dims)
gmm_optimizer = optim.Adam(gmm_model.parameters(), lr=1e-3)


# Train the model with moderate n
train_gmm_network(
    model=gmm_model,
    optimizer=gmm_optimizer,
    num_epochs=200,
    batch_size=256,
    n_min=10,
    n_max=1000,
    steps_per_epoch=100
)

# Evaluation
theta_grid = np.linspace(0, 1, 500)
y_values_fixed = [1, 10, 100, 400]
test_cases_unseen = [(20, 5), (300, 150), (900, 600)]

print("----- Evaluating GMM Fixed n=500 -----")
evaluate_gmm_fixed_n(
    model=gmm_model,
    fixed_n=500,
    y_values=y_values_fixed,
    theta_grid=theta_grid,
    num_components=K
)

print("----- Evaluating GMM Unseen n's -----")
evaluate_gmm_unseen_n(
    model=gmm_model,
    test_cases=test_cases_unseen,
    theta_grid=theta_grid,
    num_components=K
)
# Out:
# [GMM] Epoch 1/200 | Loss: -0.0650
# [GMM] Epoch 2/200 | Loss: -0.0777
# [GMM] Epoch 3/200 | Loss: -0.6125
# [GMM] Epoch 4/200 | Loss: -0.9730
# [GMM] Epoch 5/200 | Loss: -0.9741
# [GMM] Epoch 6/200 | Loss: -0.9720
# [GMM] Epoch 7/200 | Loss: -1.1030
# [GMM] Epoch 8/200 | Loss: -1.1597
# [GMM] Epoch 9/200 | Loss: -1.3764
# [GMM] Epoch 10/200 | Loss: -1.2771
# [GMM] Epoch 11/200 | Loss: -1.6658
# [GMM] Epoch 12/200 | Loss: -1.7438
# [GMM] Epoch 13/200 | Loss: -1.7035
# [GMM] Epoch 14/200 | Loss: -1.7264
# [GMM] Epoch 15/200 | Loss: -1.7591
# [GMM] Epoch 16/200 | Loss: -1.6976
# [GMM] Epoch 17/200 | Loss: -1.7799
# [GMM] Epoch 18/200 | Loss: -1.7774
# [GMM] Epoch 19/200 | Loss: -1.8187
# [GMM] Epoch 20/200 | Loss: -1.7714
# [GMM] Epoch 21/200 | Loss: -1.8013
# [GMM] Epoch 22/200 | Loss: -1.8202
# [GMM] Epoch 23/200 | Loss: -1.8140
# [GMM] Epoch 24/200 | Loss: -1.8290
# [GMM] Epoch 25/200 | Loss: -1.7804
# [GMM] Epoch 26/200 | Loss: -1.7964
# [GMM] Epoch 27/200 | Loss: -1.8105
# [GMM] Epoch 28/200 | Loss: -1.8138
# [GMM] Epoch 29/200 | Loss: -1.7496
# [GMM] Epoch 30/200 | Loss: -1.8207
# [GMM] Epoch 31/200 | Loss: -1.8128
# [GMM] Epoch 32/200 | Loss: -1.7950
# [GMM] Epoch 33/200 | Loss: -1.8136
# [GMM] Epoch 34/200 | Loss: -1.7780
# [GMM] Epoch 35/200 | Loss: -1.8291
# [GMM] Epoch 36/200 | Loss: -1.8168
# [GMM] Epoch 37/200 | Loss: -1.7943
# [GMM] Epoch 38/200 | Loss: -1.8320
# [GMM] Epoch 39/200 | Loss: -1.8442
# [GMM] Epoch 40/200 | Loss: -1.8414
# [GMM] Epoch 41/200 | Loss: -1.8353
# [GMM] Epoch 42/200 | Loss: -1.8263
# [GMM] Epoch 43/200 | Loss: -1.8183
# [GMM] Epoch 44/200 | Loss: -1.7925
# [GMM] Epoch 45/200 | Loss: -1.8429
# [GMM] Epoch 46/200 | Loss: -1.8428
# [GMM] Epoch 47/200 | Loss: -1.8342
# [GMM] Epoch 48/200 | Loss: -1.8263
# [GMM] Epoch 49/200 | Loss: -1.8337
# [GMM] Epoch 50/200 | Loss: -1.8140
# [GMM] Epoch 51/200 | Loss: -1.8272
# [GMM] Epoch 52/200 | Loss: -1.8349
# [GMM] Epoch 53/200 | Loss: -1.8549
# [GMM] Epoch 54/200 | Loss: -1.8267
# [GMM] Epoch 55/200 | Loss: -1.8608
# [GMM] Epoch 56/200 | Loss: -1.8186
# [GMM] Epoch 57/200 | Loss: -1.8351
# [GMM] Epoch 58/200 | Loss: -1.8262
# [GMM] Epoch 59/200 | Loss: -1.8523
# [GMM] Epoch 60/200 | Loss: -1.8506
# [GMM] Epoch 61/200 | Loss: -1.8602
# [GMM] Epoch 62/200 | Loss: -1.8491
# [GMM] Epoch 63/200 | Loss: -1.8450
# [GMM] Epoch 64/200 | Loss: -1.8340
# [GMM] Epoch 65/200 | Loss: -1.8622
# [GMM] Epoch 66/200 | Loss: -1.8319
# [GMM] Epoch 67/200 | Loss: -1.8581
# [GMM] Epoch 68/200 | Loss: -1.8450
# [GMM] Epoch 69/200 | Loss: -1.8201
# [GMM] Epoch 70/200 | Loss: -1.8401
# [GMM] Epoch 71/200 | Loss: -1.8547
# [GMM] Epoch 72/200 | Loss: -1.8349
# [GMM] Epoch 73/200 | Loss: -1.8658
# [GMM] Epoch 74/200 | Loss: -1.8432
# [GMM] Epoch 75/200 | Loss: -1.8423
# [GMM] Epoch 76/200 | Loss: -1.8514
# [GMM] Epoch 77/200 | Loss: -1.8391
# [GMM] Epoch 78/200 | Loss: -1.8197
# [GMM] Epoch 79/200 | Loss: -1.8400
# [GMM] Epoch 80/200 | Loss: -1.8742
# [GMM] Epoch 81/200 | Loss: -1.8587
# [GMM] Epoch 82/200 | Loss: -1.8435
# [GMM] Epoch 83/200 | Loss: -1.8624
# [GMM] Epoch 84/200 | Loss: -1.8631
# [GMM] Epoch 85/200 | Loss: -1.8410
# [GMM] Epoch 86/200 | Loss: -1.8557
# [GMM] Epoch 87/200 | Loss: -1.8326
# [GMM] Epoch 88/200 | Loss: -1.8728
# [GMM] Epoch 89/200 | Loss: -1.8548
# [GMM] Epoch 90/200 | Loss: -1.8626
# [GMM] Epoch 91/200 | Loss: -1.8619
# [GMM] Epoch 92/200 | Loss: -1.8459
# [GMM] Epoch 93/200 | Loss: -1.8523
# [GMM] Epoch 94/200 | Loss: -1.8616
# [GMM] Epoch 95/200 | Loss: -1.8463
# [GMM] Epoch 96/200 | Loss: -1.8661
# [GMM] Epoch 97/200 | Loss: -1.8714
# [GMM] Epoch 98/200 | Loss: -1.8505
# [GMM] Epoch 99/200 | Loss: -1.8449
# [GMM] Epoch 100/200 | Loss: -1.8698
# [GMM] Epoch 101/200 | Loss: -1.8546
# [GMM] Epoch 102/200 | Loss: -1.8427
# [GMM] Epoch 103/200 | Loss: -1.8780
# [GMM] Epoch 104/200 | Loss: -1.8536
# [GMM] Epoch 105/200 | Loss: -1.8507
# [GMM] Epoch 106/200 | Loss: -1.8620
# [GMM] Epoch 107/200 | Loss: -1.8653
# [GMM] Epoch 108/200 | Loss: -1.8457
# [GMM] Epoch 109/200 | Loss: -1.8641
# [GMM] Epoch 110/200 | Loss: -1.8539
# [GMM] Epoch 111/200 | Loss: -1.8789
# [GMM] Epoch 112/200 | Loss: -1.8383
# [GMM] Epoch 113/200 | Loss: -1.8754
# [GMM] Epoch 114/200 | Loss: -1.8597
# [GMM] Epoch 115/200 | Loss: -1.8683
# [GMM] Epoch 116/200 | Loss: -1.8455
# [GMM] Epoch 117/200 | Loss: -1.8737
# [GMM] Epoch 118/200 | Loss: -1.8458
# [GMM] Epoch 119/200 | Loss: -1.8664
# [GMM] Epoch 120/200 | Loss: -1.8557
# [GMM] Epoch 121/200 | Loss: -1.8802
# [GMM] Epoch 122/200 | Loss: -1.8648
# [GMM] Epoch 123/200 | Loss: -1.8361
# [GMM] Epoch 124/200 | Loss: -1.8639
# [GMM] Epoch 125/200 | Loss: -1.8701
# [GMM] Epoch 126/200 | Loss: -1.8446
# [GMM] Epoch 127/200 | Loss: -1.8554
# [GMM] Epoch 128/200 | Loss: -1.8441
# [GMM] Epoch 129/200 | Loss: -1.8771
# [GMM] Epoch 130/200 | Loss: -1.8547
# [GMM] Epoch 131/200 | Loss: -1.8729
# [GMM] Epoch 132/200 | Loss: -1.8260
# [GMM] Epoch 133/200 | Loss: -1.8479
# [GMM] Epoch 134/200 | Loss: -1.8700
# [GMM] Epoch 135/200 | Loss: -1.8722
# [GMM] Epoch 136/200 | Loss: -1.8711
# [GMM] Epoch 137/200 | Loss: -1.8722
# [GMM] Epoch 138/200 | Loss: -1.8686
# [GMM] Epoch 139/200 | Loss: -1.8637
# [GMM] Epoch 140/200 | Loss: -1.8569
# [GMM] Epoch 141/200 | Loss: -1.8694
# [GMM] Epoch 142/200 | Loss: -1.8687
# [GMM] Epoch 143/200 | Loss: -1.8746
# [GMM] Epoch 144/200 | Loss: -1.8675
# [GMM] Epoch 145/200 | Loss: -1.8741
# [GMM] Epoch 146/200 | Loss: -1.8809
# [GMM] Epoch 147/200 | Loss: -1.8407
# [GMM] Epoch 148/200 | Loss: -1.8915
# [GMM] Epoch 149/200 | Loss: -1.8840
# [GMM] Epoch 150/200 | Loss: -1.8797
# [GMM] Epoch 151/200 | Loss: -1.8641
# [GMM] Epoch 152/200 | Loss: -1.8520
# [GMM] Epoch 153/200 | Loss: -1.8761
# [GMM] Epoch 154/200 | Loss: -1.8909
# [GMM] Epoch 155/200 | Loss: -1.8684
# [GMM] Epoch 156/200 | Loss: -1.8588
# [GMM] Epoch 157/200 | Loss: -1.8819
# [GMM] Epoch 158/200 | Loss: -1.8792
# [GMM] Epoch 159/200 | Loss: -1.8687
# [GMM] Epoch 160/200 | Loss: -1.8513
# [GMM] Epoch 161/200 | Loss: -1.8682
# [GMM] Epoch 162/200 | Loss: -1.8516
# [GMM] Epoch 163/200 | Loss: -1.8673
# [GMM] Epoch 164/200 | Loss: -1.8653
# [GMM] Epoch 165/200 | Loss: -1.8630
# [GMM] Epoch 166/200 | Loss: -1.8598
# [GMM] Epoch 167/200 | Loss: -1.8479
# [GMM] Epoch 168/200 | Loss: -1.8737
# [GMM] Epoch 169/200 | Loss: -1.8814
# [GMM] Epoch 170/200 | Loss: -1.8532
# [GMM] Epoch 171/200 | Loss: -1.8763
# [GMM] Epoch 172/200 | Loss: -1.8417
# [GMM] Epoch 173/200 | Loss: -1.8849
# [GMM] Epoch 174/200 | Loss: -1.8703
# [GMM] Epoch 175/200 | Loss: -1.8549
# [GMM] Epoch 176/200 | Loss: -1.8837
# [GMM] Epoch 177/200 | Loss: -1.8924
# [GMM] Epoch 178/200 | Loss: -1.8712
# [GMM] Epoch 179/200 | Loss: -1.8709
# [GMM] Epoch 180/200 | Loss: -1.8701
# [GMM] Epoch 181/200 | Loss: -1.8753
# [GMM] Epoch 182/200 | Loss: -1.8462
# [GMM] Epoch 183/200 | Loss: -1.8799
# [GMM] Epoch 184/200 | Loss: -1.8785
# [GMM] Epoch 185/200 | Loss: -1.8614
# [GMM] Epoch 186/200 | Loss: -1.8669
# [GMM] Epoch 187/200 | Loss: -1.8819
# [GMM] Epoch 188/200 | Loss: -1.8799
# [GMM] Epoch 189/200 | Loss: -1.8731
# [GMM] Epoch 190/200 | Loss: -1.8929
# [GMM] Epoch 191/200 | Loss: -1.8681
# [GMM] Epoch 192/200 | Loss: -1.8778
# [GMM] Epoch 193/200 | Loss: -1.8696
# [GMM] Epoch 194/200 | Loss: -1.8698
# [GMM] Epoch 195/200 | Loss: -1.8748
# [GMM] Epoch 196/200 | Loss: -1.8939
# [GMM] Epoch 197/200 | Loss: -1.8818
# [GMM] Epoch 198/200 | Loss: -1.8737
# [GMM] Epoch 199/200 | Loss: -1.8836
# [GMM] Epoch 200/200 | Loss: -1.8770
# ----- Evaluating GMM Fixed n=500 -----
# ----- Evaluating GMM Unseen n's -----

# %%
K = 10
hidden_dims = (512, 512, 256, 128)
gmm_model = GMMInferenceNet(num_components=K, hidden_dims=hidden_dims)
gmm_optimizer = optim.Adam(gmm_model.parameters(), lr=1e-3)


train_gmm_network(
    model=gmm_model,
    optimizer=gmm_optimizer,
    num_epochs=200,
    batch_size=256,
    n_min=10,
    n_max=1000,
    steps_per_epoch=100
)

# Evaluation
theta_grid = np.linspace(0, 1, 500)
y_values_fixed = [1, 10, 100, 400]
test_cases_unseen = [(20, 5), (300, 150), (900, 600)]

print("----- Evaluating GMM Fixed n=500 -----")
evaluate_gmm_fixed_n(
    model=gmm_model,
    fixed_n=500,
    y_values=y_values_fixed,
    theta_grid=theta_grid,
    num_components=K
)

print("----- Evaluating GMM Unseen n's -----")
evaluate_gmm_unseen_n(
    model=gmm_model,
    test_cases=test_cases_unseen,
    theta_grid=theta_grid,
    num_components=K
)
# Out:
# [GMM] Epoch 1/200 | Loss: -0.1152
# [GMM] Epoch 2/200 | Loss: -0.0482
# [GMM] Epoch 3/200 | Loss: 0.1938
# [GMM] Epoch 4/200 | Loss: -0.4355
# [GMM] Epoch 5/200 | Loss: -1.1382
# [GMM] Epoch 6/200 | Loss: -1.5505
# [GMM] Epoch 7/200 | Loss: -1.7114
# [GMM] Epoch 8/200 | Loss: -1.7406
# [GMM] Epoch 9/200 | Loss: -1.7748
# [GMM] Epoch 10/200 | Loss: -1.7588
# [GMM] Epoch 11/200 | Loss: -1.5980
# [GMM] Epoch 12/200 | Loss: -1.7018
# [GMM] Epoch 13/200 | Loss: -1.7596
# [GMM] Epoch 14/200 | Loss: -1.7240
# [GMM] Epoch 15/200 | Loss: -1.7616
# [GMM] Epoch 16/200 | Loss: -1.7796
# [GMM] Epoch 17/200 | Loss: -1.7558
# [GMM] Epoch 18/200 | Loss: -1.8006
# [GMM] Epoch 19/200 | Loss: -1.8237
# [GMM] Epoch 20/200 | Loss: -1.5329
# [GMM] Epoch 21/200 | Loss: -1.6974
# [GMM] Epoch 22/200 | Loss: -1.8116
# [GMM] Epoch 23/200 | Loss: -1.7838
# [GMM] Epoch 24/200 | Loss: -1.8429
# [GMM] Epoch 25/200 | Loss: -1.8140
# [GMM] Epoch 26/200 | Loss: -1.6889
# [GMM] Epoch 27/200 | Loss: -1.8040
# [GMM] Epoch 28/200 | Loss: -1.7804
# [GMM] Epoch 29/200 | Loss: -1.8040
# [GMM] Epoch 30/200 | Loss: -1.8172
# [GMM] Epoch 31/200 | Loss: -1.7897
# [GMM] Epoch 32/200 | Loss: -1.8412
# [GMM] Epoch 33/200 | Loss: -1.7805
# [GMM] Epoch 34/200 | Loss: -1.7594
# [GMM] Epoch 35/200 | Loss: -1.8118
# [GMM] Epoch 36/200 | Loss: -1.7644
# [GMM] Epoch 37/200 | Loss: -1.5286
# [GMM] Epoch 38/200 | Loss: -1.7889
# [GMM] Epoch 39/200 | Loss: -1.7954
# [GMM] Epoch 40/200 | Loss: -1.8188
# [GMM] Epoch 41/200 | Loss: -1.7994
# [GMM] Epoch 42/200 | Loss: -1.8151
# [GMM] Epoch 43/200 | Loss: -1.8155
# [GMM] Epoch 44/200 | Loss: -1.8290
# [GMM] Epoch 45/200 | Loss: -1.8442
# [GMM] Epoch 46/200 | Loss: -1.8481
# [GMM] Epoch 47/200 | Loss: -1.8393
# [GMM] Epoch 48/200 | Loss: -1.7669
# [GMM] Epoch 49/200 | Loss: -1.8022
# [GMM] Epoch 50/200 | Loss: -1.8361
# [GMM] Epoch 51/200 | Loss: -1.8216
# [GMM] Epoch 52/200 | Loss: -1.8329
# [GMM] Epoch 53/200 | Loss: -1.8476
# [GMM] Epoch 54/200 | Loss: -1.8364
# [GMM] Epoch 55/200 | Loss: -1.8352
# [GMM] Epoch 56/200 | Loss: -1.8134
# [GMM] Epoch 57/200 | Loss: -1.8559
# [GMM] Epoch 58/200 | Loss: -1.8412
# [GMM] Epoch 59/200 | Loss: -1.8408
# [GMM] Epoch 60/200 | Loss: -1.8401
# [GMM] Epoch 61/200 | Loss: -1.8430
# [GMM] Epoch 62/200 | Loss: -1.8580
# [GMM] Epoch 63/200 | Loss: -1.8407
# [GMM] Epoch 64/200 | Loss: -1.8380
# [GMM] Epoch 65/200 | Loss: -1.8641
# [GMM] Epoch 66/200 | Loss: -1.8438
# [GMM] Epoch 67/200 | Loss: -1.8313
# [GMM] Epoch 68/200 | Loss: -1.8294
# [GMM] Epoch 69/200 | Loss: -1.8330
# [GMM] Epoch 70/200 | Loss: -1.8569
# [GMM] Epoch 71/200 | Loss: -1.8274
# [GMM] Epoch 72/200 | Loss: -1.8388
# [GMM] Epoch 73/200 | Loss: -1.8420
# [GMM] Epoch 74/200 | Loss: -1.8557
# [GMM] Epoch 75/200 | Loss: -1.8501
# [GMM] Epoch 76/200 | Loss: -1.8666
# [GMM] Epoch 77/200 | Loss: -1.8468
# [GMM] Epoch 78/200 | Loss: -1.8493
# [GMM] Epoch 79/200 | Loss: -1.8237
# [GMM] Epoch 80/200 | Loss: -1.8607
# [GMM] Epoch 81/200 | Loss: -1.8741
# [GMM] Epoch 82/200 | Loss: -1.8531
# [GMM] Epoch 83/200 | Loss: -1.8483
# [GMM] Epoch 84/200 | Loss: -1.8664
# [GMM] Epoch 85/200 | Loss: -1.8507
# [GMM] Epoch 86/200 | Loss: -1.8511
# [GMM] Epoch 87/200 | Loss: -1.8527
# [GMM] Epoch 88/200 | Loss: -1.8486
# [GMM] Epoch 89/200 | Loss: -1.8591
# [GMM] Epoch 90/200 | Loss: -1.8785
# [GMM] Epoch 91/200 | Loss: -1.8488
# [GMM] Epoch 92/200 | Loss: -1.8640
# [GMM] Epoch 93/200 | Loss: -1.8396
# [GMM] Epoch 94/200 | Loss: -1.8612
# [GMM] Epoch 95/200 | Loss: -1.8635
# [GMM] Epoch 96/200 | Loss: -1.8476
# [GMM] Epoch 97/200 | Loss: -1.8219
# [GMM] Epoch 98/200 | Loss: -1.8676
# [GMM] Epoch 99/200 | Loss: -1.8490
# [GMM] Epoch 100/200 | Loss: -1.8637
# [GMM] Epoch 101/200 | Loss: -1.8594
# [GMM] Epoch 102/200 | Loss: -1.8465
# [GMM] Epoch 103/200 | Loss: -1.8774
# [GMM] Epoch 104/200 | Loss: -1.8738
# [GMM] Epoch 105/200 | Loss: -1.8675
# [GMM] Epoch 106/200 | Loss: -1.8829
# [GMM] Epoch 107/200 | Loss: -1.8587
# [GMM] Epoch 108/200 | Loss: -1.8714
# [GMM] Epoch 109/200 | Loss: -1.8625
# [GMM] Epoch 110/200 | Loss: -1.8553
# [GMM] Epoch 111/200 | Loss: -1.8585
# [GMM] Epoch 112/200 | Loss: -1.8632
# [GMM] Epoch 113/200 | Loss: -1.8769
# [GMM] Epoch 114/200 | Loss: -1.8660
# [GMM] Epoch 115/200 | Loss: -1.8680
# [GMM] Epoch 116/200 | Loss: -1.8677
# [GMM] Epoch 117/200 | Loss: -1.8738
# [GMM] Epoch 118/200 | Loss: -1.8637
# [GMM] Epoch 119/200 | Loss: -1.8532
# [GMM] Epoch 120/200 | Loss: -1.8576
# [GMM] Epoch 121/200 | Loss: -1.8774
# [GMM] Epoch 122/200 | Loss: -1.8592
# [GMM] Epoch 123/200 | Loss: -1.8700
# [GMM] Epoch 124/200 | Loss: -1.8553
# [GMM] Epoch 125/200 | Loss: -1.8639
# [GMM] Epoch 126/200 | Loss: -1.8622
# [GMM] Epoch 127/200 | Loss: -1.8574
# [GMM] Epoch 128/200 | Loss: -1.8558
# [GMM] Epoch 129/200 | Loss: -1.8555
# [GMM] Epoch 130/200 | Loss: -1.8737
# [GMM] Epoch 131/200 | Loss: -1.8484
# [GMM] Epoch 132/200 | Loss: -1.8894
# [GMM] Epoch 133/200 | Loss: -1.8609
# [GMM] Epoch 134/200 | Loss: -1.8771
# [GMM] Epoch 135/200 | Loss: -1.8795
# [GMM] Epoch 136/200 | Loss: -1.8717
# [GMM] Epoch 137/200 | Loss: -1.8763
# [GMM] Epoch 138/200 | Loss: -1.8607
# [GMM] Epoch 139/200 | Loss: -1.8693
# [GMM] Epoch 140/200 | Loss: -1.8676
# [GMM] Epoch 141/200 | Loss: -1.8825
# [GMM] Epoch 142/200 | Loss: -1.8532
# [GMM] Epoch 143/200 | Loss: -1.8714
# [GMM] Epoch 144/200 | Loss: -1.8804
# [GMM] Epoch 145/200 | Loss: -1.8613
# [GMM] Epoch 146/200 | Loss: -1.8598
# [GMM] Epoch 147/200 | Loss: -1.8718
# [GMM] Epoch 148/200 | Loss: -1.8634
# [GMM] Epoch 149/200 | Loss: -1.8581
# [GMM] Epoch 150/200 | Loss: -1.8722
# [GMM] Epoch 151/200 | Loss: -1.8678
# [GMM] Epoch 152/200 | Loss: -1.8536
# [GMM] Epoch 153/200 | Loss: -1.8609
# [GMM] Epoch 154/200 | Loss: -1.8579
# [GMM] Epoch 155/200 | Loss: -1.8758
# [GMM] Epoch 156/200 | Loss: -1.8751
# [GMM] Epoch 157/200 | Loss: -1.8724
# [GMM] Epoch 158/200 | Loss: -1.8740
# [GMM] Epoch 159/200 | Loss: -1.8634
# [GMM] Epoch 160/200 | Loss: -1.8757
# [GMM] Epoch 161/200 | Loss: -1.8726
# [GMM] Epoch 162/200 | Loss: -1.8730
# [GMM] Epoch 163/200 | Loss: -1.8782
# [GMM] Epoch 164/200 | Loss: -1.8907
# [GMM] Epoch 165/200 | Loss: -1.9008
# [GMM] Epoch 166/200 | Loss: -1.8747
# [GMM] Epoch 167/200 | Loss: -1.8744
# [GMM] Epoch 168/200 | Loss: -1.8653
# [GMM] Epoch 169/200 | Loss: -1.8736
# [GMM] Epoch 170/200 | Loss: -1.8623
# [GMM] Epoch 171/200 | Loss: -1.8663
# [GMM] Epoch 172/200 | Loss: -1.8603
# [GMM] Epoch 173/200 | Loss: -1.8726
# [GMM] Epoch 174/200 | Loss: -1.8690
# [GMM] Epoch 175/200 | Loss: -1.8725
# [GMM] Epoch 176/200 | Loss: -1.8793
# [GMM] Epoch 177/200 | Loss: -1.8865
# [GMM] Epoch 178/200 | Loss: -1.8653
# [GMM] Epoch 179/200 | Loss: -1.8680
# [GMM] Epoch 180/200 | Loss: -1.8517
# [GMM] Epoch 181/200 | Loss: -1.8840
# [GMM] Epoch 182/200 | Loss: -1.9020
# [GMM] Epoch 183/200 | Loss: -1.8802
# [GMM] Epoch 184/200 | Loss: -1.8657
# [GMM] Epoch 185/200 | Loss: -1.8904
# [GMM] Epoch 186/200 | Loss: -1.8838
# [GMM] Epoch 187/200 | Loss: -1.8599
# [GMM] Epoch 188/200 | Loss: -1.8757
# [GMM] Epoch 189/200 | Loss: -1.8768
# [GMM] Epoch 190/200 | Loss: -1.8829
# [GMM] Epoch 191/200 | Loss: -1.8850
# [GMM] Epoch 192/200 | Loss: -1.8894
# [GMM] Epoch 193/200 | Loss: -1.8786
# [GMM] Epoch 194/200 | Loss: -1.8773
# [GMM] Epoch 195/200 | Loss: -1.8637
# [GMM] Epoch 196/200 | Loss: -1.8813
# [GMM] Epoch 197/200 | Loss: -1.8870
# [GMM] Epoch 198/200 | Loss: -1.8848
# [GMM] Epoch 199/200 | Loss: -1.8736
# [GMM] Epoch 200/200 | Loss: -1.8775
# ----- Evaluating GMM Fixed n=500 -----
# ----- Evaluating GMM Unseen n's -----

# %%
K = 10
hidden_dims = (512, 512, 256, 128)
gmm_model = GMMInferenceNet(num_components=K, hidden_dims=hidden_dims)
gmm_optimizer = optim.Adam(gmm_model.parameters(), lr=1e-3)


train_gmm_network(
    model=gmm_model,
    optimizer=gmm_optimizer,
    num_epochs=200,
    batch_size=256,
    n_min=100,
    n_max=10000,
    steps_per_epoch=100
)

# Evaluation
theta_grid = np.linspace(0, 1, 500)
y_values_fixed = [1, 100, 1000, 2000, 5000]
test_cases_unseen = [(200, 50), (5000, 2500), (10000, 9000)]

print("----- Evaluating GMM Fixed n=5000 -----")
evaluate_gmm_fixed_n(
    model=gmm_model,
    fixed_n=5000,
    y_values=y_values_fixed,
    theta_grid=theta_grid,
    num_components=K
)

print("----- Evaluating GMM Unseen n's -----")
evaluate_gmm_unseen_n(
    model=gmm_model,
    test_cases=test_cases_unseen,
    theta_grid=theta_grid,
    num_components=K
)
# Out:
# [GMM] Epoch 1/200 | Loss: 0.2084
# [GMM] Epoch 2/200 | Loss: -0.2147
# [GMM] Epoch 3/200 | Loss: -0.4957
# [GMM] Epoch 4/200 | Loss: -0.1100
# [GMM] Epoch 5/200 | Loss: -0.2921
# [GMM] Epoch 6/200 | Loss: -0.7254
# [GMM] Epoch 7/200 | Loss: 0.0748
# [GMM] Epoch 8/200 | Loss: 0.0685
# [GMM] Epoch 9/200 | Loss: 0.2735
# [GMM] Epoch 10/200 | Loss: -0.0038
# [GMM] Epoch 11/200 | Loss: 0.3552
# [GMM] Epoch 12/200 | Loss: 0.0814
# [GMM] Epoch 13/200 | Loss: -0.4151
# [GMM] Epoch 14/200 | Loss: -0.5585
# [GMM] Epoch 15/200 | Loss: -1.0532
# [GMM] Epoch 16/200 | Loss: -0.4640
# [GMM] Epoch 17/200 | Loss: -0.5909
# [GMM] Epoch 18/200 | Loss: -1.3123
# [GMM] Epoch 19/200 | Loss: -1.3509
# [GMM] Epoch 20/200 | Loss: -1.6212
# [GMM] Epoch 21/200 | Loss: -1.9747
# [GMM] Epoch 22/200 | Loss: -1.9783
# [GMM] Epoch 23/200 | Loss: -2.3353
# [GMM] Epoch 24/200 | Loss: -2.4758
# [GMM] Epoch 25/200 | Loss: -2.4939
# [GMM] Epoch 26/200 | Loss: -2.2376
# [GMM] Epoch 27/200 | Loss: -2.5973
# [GMM] Epoch 28/200 | Loss: -2.5747
# [GMM] Epoch 29/200 | Loss: -2.5733
# [GMM] Epoch 30/200 | Loss: -2.2203
# [GMM] Epoch 31/200 | Loss: -2.5334
# [GMM] Epoch 32/200 | Loss: -2.6474
# [GMM] Epoch 33/200 | Loss: -2.5928
# [GMM] Epoch 34/200 | Loss: -2.6352
# [GMM] Epoch 35/200 | Loss: -2.6283
# [GMM] Epoch 36/200 | Loss: -2.4731
# [GMM] Epoch 37/200 | Loss: -2.3368
# [GMM] Epoch 38/200 | Loss: -2.6390
# [GMM] Epoch 39/200 | Loss: -2.1948
# [GMM] Epoch 40/200 | Loss: -2.5775
# [GMM] Epoch 41/200 | Loss: -2.6095
# [GMM] Epoch 42/200 | Loss: -2.6319
# [GMM] Epoch 43/200 | Loss: -2.6150
# [GMM] Epoch 44/200 | Loss: -2.6529
# [GMM] Epoch 45/200 | Loss: -2.5962
# [GMM] Epoch 46/200 | Loss: -2.6174
# [GMM] Epoch 47/200 | Loss: -2.6240
# [GMM] Epoch 48/200 | Loss: -2.6237
# [GMM] Epoch 49/200 | Loss: -2.6333
# [GMM] Epoch 50/200 | Loss: -2.6158
# [GMM] Epoch 51/200 | Loss: -2.5489
# [GMM] Epoch 52/200 | Loss: -2.6301
# [GMM] Epoch 53/200 | Loss: -2.6601
# [GMM] Epoch 54/200 | Loss: -2.5936
# [GMM] Epoch 55/200 | Loss: -2.6057
# [GMM] Epoch 56/200 | Loss: -2.6308
# [GMM] Epoch 57/200 | Loss: -2.6923
# [GMM] Epoch 58/200 | Loss: -2.6443
# [GMM] Epoch 59/200 | Loss: -2.6851
# [GMM] Epoch 60/200 | Loss: -2.6349
# [GMM] Epoch 61/200 | Loss: -2.6650
# [GMM] Epoch 62/200 | Loss: -2.6370
# [GMM] Epoch 63/200 | Loss: -2.5738
# [GMM] Epoch 64/200 | Loss: -2.6719
# [GMM] Epoch 65/200 | Loss: -2.6766
# [GMM] Epoch 66/200 | Loss: -2.6010
# [GMM] Epoch 67/200 | Loss: -2.6542
# [GMM] Epoch 68/200 | Loss: -2.6646
# [GMM] Epoch 69/200 | Loss: -2.6298
# [GMM] Epoch 70/200 | Loss: -2.7602
# [GMM] Epoch 71/200 | Loss: -2.6319
# [GMM] Epoch 72/200 | Loss: -2.5080
# [GMM] Epoch 73/200 | Loss: -2.5929
# [GMM] Epoch 74/200 | Loss: -2.6030
# [GMM] Epoch 75/200 | Loss: -2.4592
# [GMM] Epoch 76/200 | Loss: -2.5143
# [GMM] Epoch 77/200 | Loss: -2.6702
# [GMM] Epoch 78/200 | Loss: -2.6325
# [GMM] Epoch 79/200 | Loss: -2.3057
# [GMM] Epoch 80/200 | Loss: -2.7292
# [GMM] Epoch 81/200 | Loss: -2.6964
# [GMM] Epoch 82/200 | Loss: -2.7540
# [GMM] Epoch 83/200 | Loss: -2.7240
# [GMM] Epoch 84/200 | Loss: -2.7201
# [GMM] Epoch 85/200 | Loss: -2.3726
# [GMM] Epoch 86/200 | Loss: -2.6050
# [GMM] Epoch 87/200 | Loss: -2.6400
# [GMM] Epoch 88/200 | Loss: -2.6462
# [GMM] Epoch 89/200 | Loss: -2.6565
# [GMM] Epoch 90/200 | Loss: -2.6461
# [GMM] Epoch 91/200 | Loss: -2.6545
# [GMM] Epoch 92/200 | Loss: -2.6929
# [GMM] Epoch 93/200 | Loss: -2.6510
# [GMM] Epoch 94/200 | Loss: -2.6928
# [GMM] Epoch 95/200 | Loss: -2.6670
# [GMM] Epoch 96/200 | Loss: -2.6787
# [GMM] Epoch 97/200 | Loss: -2.7112
# [GMM] Epoch 98/200 | Loss: -2.7048
# [GMM] Epoch 99/200 | Loss: -2.7016
# [GMM] Epoch 100/200 | Loss: -2.7065
# [GMM] Epoch 101/200 | Loss: -2.6131
# [GMM] Epoch 102/200 | Loss: -2.6919
# [GMM] Epoch 103/200 | Loss: -2.6777
# [GMM] Epoch 104/200 | Loss: -2.6502
# [GMM] Epoch 105/200 | Loss: -2.7154
# [GMM] Epoch 106/200 | Loss: -2.6932
# [GMM] Epoch 107/200 | Loss: -2.7054
# [GMM] Epoch 108/200 | Loss: -2.6624
# [GMM] Epoch 109/200 | Loss: -2.6520
# [GMM] Epoch 110/200 | Loss: -2.6708
# [GMM] Epoch 111/200 | Loss: -2.5966
# [GMM] Epoch 112/200 | Loss: -2.6374
# [GMM] Epoch 113/200 | Loss: -2.7066
# [GMM] Epoch 114/200 | Loss: -2.6577
# [GMM] Epoch 115/200 | Loss: -2.7076
# [GMM] Epoch 116/200 | Loss: -2.6987
# [GMM] Epoch 117/200 | Loss: -2.6903
# [GMM] Epoch 118/200 | Loss: -2.7048
# [GMM] Epoch 119/200 | Loss: -2.6806
# [GMM] Epoch 120/200 | Loss: -2.6685
# [GMM] Epoch 121/200 | Loss: -2.6900
# [GMM] Epoch 122/200 | Loss: -2.6930
# [GMM] Epoch 123/200 | Loss: -2.7022
# [GMM] Epoch 124/200 | Loss: -2.7109
# [GMM] Epoch 125/200 | Loss: -2.6992
# [GMM] Epoch 126/200 | Loss: -2.7203
# [GMM] Epoch 127/200 | Loss: -2.7052
# [GMM] Epoch 128/200 | Loss: -2.6987
# [GMM] Epoch 129/200 | Loss: -2.6951
# [GMM] Epoch 130/200 | Loss: -2.7234
# [GMM] Epoch 131/200 | Loss: -2.6922
# [GMM] Epoch 132/200 | Loss: -2.6889
# [GMM] Epoch 133/200 | Loss: -2.6700
# [GMM] Epoch 134/200 | Loss: -2.6912
# [GMM] Epoch 135/200 | Loss: -2.7040
# [GMM] Epoch 136/200 | Loss: -2.6510
# [GMM] Epoch 137/200 | Loss: -2.7046
# [GMM] Epoch 138/200 | Loss: -2.6973
# [GMM] Epoch 139/200 | Loss: -2.7277
# [GMM] Epoch 140/200 | Loss: -2.6938
# [GMM] Epoch 141/200 | Loss: -2.6800
# [GMM] Epoch 142/200 | Loss: -2.7107
# [GMM] Epoch 143/200 | Loss: -2.6861
# [GMM] Epoch 144/200 | Loss: -2.6774
# [GMM] Epoch 145/200 | Loss: -2.6185
# [GMM] Epoch 146/200 | Loss: -2.6953
# [GMM] Epoch 147/200 | Loss: -2.7140
# [GMM] Epoch 148/200 | Loss: -2.7254
# [GMM] Epoch 149/200 | Loss: -2.6874
# [GMM] Epoch 150/200 | Loss: -2.7054
# [GMM] Epoch 151/200 | Loss: -2.7087
# [GMM] Epoch 152/200 | Loss: -2.6823
# [GMM] Epoch 153/200 | Loss: -2.7064
# [GMM] Epoch 154/200 | Loss: -2.7247
# [GMM] Epoch 155/200 | Loss: -2.7044
# [GMM] Epoch 156/200 | Loss: -2.6995
# [GMM] Epoch 157/200 | Loss: -2.6823
# [GMM] Epoch 158/200 | Loss: -2.7141
# [GMM] Epoch 159/200 | Loss: -2.6947
# [GMM] Epoch 160/200 | Loss: -2.6953
# [GMM] Epoch 161/200 | Loss: -2.7033
# [GMM] Epoch 162/200 | Loss: -2.6700
# [GMM] Epoch 163/200 | Loss: -2.6736
# [GMM] Epoch 164/200 | Loss: -2.7141
# [GMM] Epoch 165/200 | Loss: -2.7135
# [GMM] Epoch 166/200 | Loss: -2.7175
# [GMM] Epoch 167/200 | Loss: -2.6762
# [GMM] Epoch 168/200 | Loss: -2.7304
# [GMM] Epoch 169/200 | Loss: -2.6533
# [GMM] Epoch 170/200 | Loss: -2.6833
# [GMM] Epoch 171/200 | Loss: -2.5239
# [GMM] Epoch 172/200 | Loss: -2.7083
# [GMM] Epoch 173/200 | Loss: -2.6977
# [GMM] Epoch 174/200 | Loss: -2.7122
# [GMM] Epoch 175/200 | Loss: -2.6849
# [GMM] Epoch 176/200 | Loss: -2.6820
# [GMM] Epoch 177/200 | Loss: -2.6825
# [GMM] Epoch 178/200 | Loss: -2.7136
# [GMM] Epoch 179/200 | Loss: -2.7176
# [GMM] Epoch 180/200 | Loss: -2.6786
# [GMM] Epoch 181/200 | Loss: -2.7163
# [GMM] Epoch 182/200 | Loss: -2.6933
# [GMM] Epoch 183/200 | Loss: -2.6991
# [GMM] Epoch 184/200 | Loss: -2.7356
# [GMM] Epoch 185/200 | Loss: -2.7071
# [GMM] Epoch 186/200 | Loss: -2.6990
# [GMM] Epoch 187/200 | Loss: -2.7174
# [GMM] Epoch 188/200 | Loss: -2.7401
# [GMM] Epoch 189/200 | Loss: -2.6941
# [GMM] Epoch 190/200 | Loss: -2.6887
# [GMM] Epoch 191/200 | Loss: -2.7177
# [GMM] Epoch 192/200 | Loss: -2.7233
# [GMM] Epoch 193/200 | Loss: -2.7006
# [GMM] Epoch 194/200 | Loss: -2.7232
# [GMM] Epoch 195/200 | Loss: -2.6939
# [GMM] Epoch 196/200 | Loss: -2.7049
# [GMM] Epoch 197/200 | Loss: -2.7192
# [GMM] Epoch 198/200 | Loss: -2.7275
# [GMM] Epoch 199/200 | Loss: -2.6484
# [GMM] Epoch 200/200 | Loss: -2.7301
# ----- Evaluating GMM Fixed n=5000 -----
# ----- Evaluating GMM Unseen n's -----

# %%
# Evaluation
theta_grid = np.linspace(0, 1, 500)
y_values_fixed = [1, 100, 1000, 2000, 5000]
test_cases_unseen = [(200, 50), (5000, 2500), (10000, 9000)]

print("----- Evaluating GMM Fixed n=5000 -----")
evaluate_gmm_fixed_n(
    model=gmm_model,
    fixed_n=5000,
    y_values=y_values_fixed,
    theta_grid=theta_grid,
    num_components=K
)

print("----- Evaluating GMM Unseen n's -----")
evaluate_gmm_unseen_n(
    model=gmm_model,
    test_cases=test_cases_unseen,
    theta_grid=theta_grid,
    num_components=K
)
# Out:
# ----- Evaluating GMM Fixed n=5000 -----
# ----- Evaluating GMM Unseen n's -----
